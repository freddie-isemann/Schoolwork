// %% [markdown]
// ```
// public static void virus() {
//   String plea = new String();
//   String[] code = new String[16];
//     code[0] = "public static void virus() {%c";
//     code[1] = "  String plea = new String();%c";
//     code[2] = "  String[] code = new String[16];%c";
//     code[3] = "    code[%d] = %c%s%c;%c";
//     code[4] = "%c";
//     code[5] = "  char n = 10, q = 34;%c";
//     code[6] = "  for (int i = 0; i < 3; i++)%c";
//     code[7] = "    plea += String.format(code[i], n);%c";
//     code[8] = "  for (int i = 0; i < 16; i++)%c";
//     code[9] = "    plea += String.format(code[3], i,q,code[i],q,n);%c";
//     code[10] = "  for (int i = 4; i < 16; i++)%c";
//     code[11] = "    plea += String.format(code[i], n);%c";
//     code[12] = "%c";
//     code[13] = "  System.out.println(plea);%c";
//     code[14] = "}%c";
//     code[15] = "virus(); // Please copy all this into the box below and run.%c";
//
//   char n = 10, q = 34;
//   for (int i = 0; i < 3; i++)
//     plea += String.format(code[i], n);
//   for (int i = 0; i < 16; i++)
//     plea += String.format(code[3], i,q,code[i],q,n);
//   for (int i = 4; i < 16; i++)
//     plea += String.format(code[i], n);
//
//   System.out.println(plea);
// }
// virus(); // Please copy all this into the box below and run.
// ```

// %%
public static void virus() {
  String plea = new String();
  String[] code = new String[16];
    code[0] = "public static void virus() {%c";
    code[1] = "  String plea = new String();%c";
    code[2] = "  String[] code = new String[16];%c";
    code[3] = "    code[%d] = %c%s%c;%c";
    code[4] = "%c";
    code[5] = "  char n = 10, q = 34;%c";
    code[6] = "  for (int i = 0; i < 3; i++)%c";
    code[7] = "    plea += String.format(code[i], n);%c";
    code[8] = "  for (int i = 0; i < 16; i++)%c";
    code[9] = "    plea += String.format(code[3], i,q,code[i],q,n);%c";
    code[10] = "  for (int i = 4; i < 16; i++)%c";
    code[11] = "    plea += String.format(code[i], n);%c";
    code[12] = "%c";
    code[13] = "  System.out.println(plea);%c";
    code[14] = "}%c";
    code[15] = "virus(); // Please copy all this into the box below and run.%c";
    
  char n = 10, q = 34;
  for (int i = 0; i < 3; i++)
    plea += String.format(code[i], n); 
  for (int i = 0; i < 16; i++)
    plea += String.format(code[3], i,q,code[i],q,n);   
  for (int i = 4; i < 16; i++)
    plea += String.format(code[i], n); 
    
  System.out.println(plea);
}
virus(); // Please copy all this into the box below and run.
// Out:
// public static void virus() {
//   String plea = new String();
//   String[] code = new String[16];
//     code[0] = "public static void virus() {%c";
//     code[1] = "  String plea = new String();%c";
//     code[2] = "  String[] code = new String[16];%c";
//     code[3] = "    code[%d] = %c%s%c;%c";
//     code[4] = "%c";
//     code[5] = "  char n = 10, q = 34;%c";
//     code[6] = "  for (int i = 0; i < 3; i++)%c";
//     code[7] = "    plea += String.format(code[i], n);%c";
//     code[8] = "  for (int i = 0; i < 16; i++)%c";
//     code[9] = "    plea += String.format(code[3], i,q,code[i],q,n);%c";
//     code[10] = "  for (int i = 4; i < 16; i++)%c";
//     code[11] = "    plea += String.format(code[i], n);%c";
//     code[12] = "%c";
//     code[13] = "  System.out.println(plea);%c";
//     code[14] = "}%c";
//     code[15] = "virus(); // Please copy all this into the box below and run.%c";
//
//   char n = 10, q = 34;
//   for (int i = 0; i < 3; i++)
// ...
